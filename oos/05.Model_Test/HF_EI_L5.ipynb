# %% [markdown]
# base_model 허깅페이스(https://huggingface.co/Anwarkh1/Skin_Cancer-Image_Classification)
# 모델 가중치 업데이트 가능한 상태로 테스트
# 데이터 : 이마(색소침착, 0-5)
# 가중치 : 데이터 분포에 따른 가중치 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torchvision import transforms, models
from transformers import AutoModelForImageClassification

# %%
from transformers import AutoModel, AutoTokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def Image_feature_selector(data_sets, enhance):
    import cv2
    import numpy as np
    from PIL import Image  # PIL 추가

    new_image = {}
    file_name = data_sets["Images"].keys()
    for file_key in file_name:

        # 이미지 불러오기
        image = data_sets['Images'][file_key]

        # 어두운 영역을 감지하기 위해 이미지를 그레이스케일로 변환
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # 이미지의 평균 밝기 계산
        mean_brightness = np.mean(gray_image) + enhance

        # 평균 밝기를 기준으로 어두운 영역 마스크 생성
        _, dark_mask = cv2.threshold(gray_image, mean_brightness - 20, 255, cv2.THRESH_BINARY_INV)

        # 어두운 영역을 강조하기 위해 밝기와 대비 증가
        enhanced_image = image.copy()
        enhanced_image[dark_mask > 0] = cv2.addWeighted(enhanced_image[dark_mask > 0], 1.8, np.zeros_like(enhanced_image[dark_mask > 0]), 0, 60)

        # numpy 배열을 PIL.Image로 변환
        new_image[file_key] = Image.fromarray(cv2.cvtColor(enhanced_image, cv2.COLOR_BGR2RGB))  # OpenCV는 BGR, PIL은 RGB 사용

    return new_image

# %%
# GPU 여부 확인
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
# 데이터 준비 1. 핸드폰, 전면, 이마, 메타데이터 전체
# 테스트데이터
path = "/content/drive/MyDrive/Human_Final_Project/Data/Train_Data_Sets_02.pkl"
with open(path, "rb") as pickle_file:
    train_data_sets = pickle.load(pickle_file)
    print("데이터 로드 완료!!")
# Out:
# 데이터 로드 완료!!

# %%
# 검증데이터
path = "/content/drive/MyDrive/Human_Final_Project/Data/Val_Data_Sets_02.pkl"
with open(path, "rb") as pickle_file:
    val_data_sets = pickle.load(pickle_file)
    print("데이터 로드 완료!!")
# Out:
# 데이터 로드 완료!!

# %%
# 이미지 이름 추출
file_name = train_data_sets['Images'].keys()
file_list = []
for file_keys in file_name:
    file_list.append(file_keys)
# Out:
# list

# %%
#이미지 강조
new_image = Image_feature_selector(train_data_sets, 10)
new_val_image = Image_feature_selector(val_data_sets, 10)

# %%
# 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 모델 입력 크기에 맞추기
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet 기준 정규화
])

# %%
class CustomDataset(Dataset):
    def __init__(self, data_sets, new_image, transform=transform):
        self.images = new_image
        self.metadata = data_sets['Metadata']
        self.keys = list(self.images.keys())
        self.transform = transform

    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        image = self.images[key]
        if self.transform:
            image = self.transform(image)

        target = torch.tensor(self.metadata[key]['annotations']['forehead_pigmentation'], dtype=torch.float32)
        return image, target

# %%
#데이터셋 생성 (텐서형태로 변환)
dataset = CustomDataset(train_data_sets, new_image)
val_dataset = CustomDataset(val_data_sets, new_val_image)

# %%
#로더를 이용해 데이터 배치화
train_loader = torch.utils.data.DataLoader(dataset, batch_size=8, shuffle=True)
test_loader = torch.utils.data.DataLoader(val_dataset, batch_size=8, shuffle=True)

# %%
# 허깅페이스 베이스 모델을 이용한 모델 설계
class SkinNet(nn.Module):
    def __init__(self):
        super(SkinNet, self).__init__()
        # 사전 학습된 모델 로드
        self.base_model = AutoModelForImageClassification.from_pretrained(
            "Anwarkh1/Skin_Cancer-Image_Classification",
            ignore_mismatched_sizes=True
        )

        # 사전 학습된 모델의 출력 크기 확인
        num_features = self.base_model.classifier.out_features

        # 사용자 정의 레이어 추가
        self.fc1 = nn.Linear(num_features, 128)  # 128은 임의로 설정한 크기
        self.fc2 = nn.Linear(128, 6)  # 최종 클래스 수 (6)

    def forward(self, x):
        # 사전 학습된 모델에서 logits 추출
        outputs = self.base_model(x)
        x = outputs.logits  # logits만 가져옴

        # 사용자 정의 레이어를 통과
        x = self.fc1(x)
        x = nn.ReLU()(x)  # 활성화 함수 추가
        x = self.fc2(x)
        return x  # 최종 로짓 값 반환

# %%
#criterion에 적용할 데이터 분포 기반 가중치 조절

# 클래스별 샘플 수
class_counts = torch.tensor([175, 443, 163, 69, 6, 2], dtype=torch.float)

# 전체 샘플 수
total_samples = class_counts.sum()

# 클래스 가중치 계산
num_classes = len(class_counts)
class_weights = total_samples / (num_classes * class_counts)

print("Class Weights:", class_weights)
# Out:
# Class Weights: tensor([ 0.8171,  0.3228,  0.8773,  2.0725, 23.8333, 71.5000])

# %%
model = SkinNet().to(device)
#print(model)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.01k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/343M [00:00<?, ?B/s]

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.000001)

# %%
def train(model, train_loader, optimizer):
    loss_total = 0
    correct_total = 0
    model.train()
    for idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device).long()

        optimizer.zero_grad()

        output = model(images)
        loss = criterion(output, labels)

        loss.backward()
        optimizer.step()

        # 누적 손실 및 정확도 계산
        loss_total += loss.item()
        predicted_values = output.max(1, keepdim=True)[1]
        correct = predicted_values.eq(labels.view_as(predicted_values)).sum().item()
        correct_total += correct



        # 에폭 종료 후 평균 손실 및 정확도 계산
    loss_total /= len(train_loader)  # 배치 개수로 나누어 평균 계산
    accuracy = correct_total / len(train_loader.dataset)  # 전체 데이터셋에서 정확도 계산

    # 마지막 배치 후 결과 출력
    print(f"Train Finished - Train_Loss: {loss_total:.4f}, Train_Accuracy: {accuracy:.4f}")

    return loss_total, accuracy

# %%
def evaluate(model, test_loader):
    loss_total = 0
    correct_total = 0
    predict_history = []
    label_history = []
    total_count = 0
    model.eval() # evaluation mode로 설정 -> batch-normalization, drop-out 수행 중지
    with torch.no_grad(): # 가중치 업데이트 수행 중지
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device).long()
            output = model(images)
            loss = criterion(output, labels).item()
            loss_total += loss
            predicted_values = output.max(1, keepdim=True)[1]
            correct = predicted_values.eq(labels.view_as(predicted_values)).sum().item()
            # pdb.set_trace()
            correct_total += correct
            total_count += len(predicted_values)

            predict_history.append(predicted_values)
            label_history.append(labels)

    loss_total /= ( total_count / 8 )
    accuracy = correct_total / total_count

    return loss_total, accuracy, predict_history, label_history

# %%
# 학습 실행
for epoch in range(100):
    train(model, train_loader, optimizer)
    val_loss, val_accuracy, val_predict_history, val_label_history = evaluate(model, test_loader)
    print(f"Epoch : {epoch + 1}, val_Loss: {val_loss}, val_Accuracy : {val_accuracy}", '\n')
# Out:
# Train Finished - Train_Loss: 1.7318, Train_Accuracy: 0.2343
# Epoch : 1, val_Loss: 1.8560793956863546, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.6433, Train_Accuracy: 0.3112
# Epoch : 2, val_Loss: 1.8043910320674148, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 1.6157, Train_Accuracy: 0.4126
# Epoch : 3, val_Loss: 1.7634017088702907, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 1.5850, Train_Accuracy: 0.4359
# Epoch : 4, val_Loss: 1.7978142622475313, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 1.5784, Train_Accuracy: 0.4732
# Epoch : 5, val_Loss: 1.7888288497924805, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.5499, Train_Accuracy: 0.4977
# Epoch : 6, val_Loss: 1.7224651675357996, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 1.5376, Train_Accuracy: 0.4872
# Epoch : 7, val_Loss: 1.7620456642079576, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.5270, Train_Accuracy: 0.4977
# Epoch : 8, val_Loss: 1.6868156094417395, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 1.5176, Train_Accuracy: 0.5070
# Epoch : 9, val_Loss: 1.7516468707646164, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 1.5023, Train_Accuracy: 0.5082
# Epoch : 10, val_Loss: 1.6734546144431997, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.4890, Train_Accuracy: 0.5221
# Epoch : 11, val_Loss: 1.7243774093200113, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 1.4725, Train_Accuracy: 0.5140
# Epoch : 12, val_Loss: 1.7279452208046602, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.4644, Train_Accuracy: 0.5280
# Epoch : 13, val_Loss: 1.6609791015910211, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 1.4527, Train_Accuracy: 0.5350
# Epoch : 14, val_Loss: 1.7270436064105168, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 1.4371, Train_Accuracy: 0.5408
# Epoch : 15, val_Loss: 1.6490315499706802, val_Accuracy : 0.5420560747663551
#
# Train Finished - Train_Loss: 1.4323, Train_Accuracy: 0.5291
# Epoch : 16, val_Loss: 1.6431044819199037, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.4201, Train_Accuracy: 0.5571
# Epoch : 17, val_Loss: 1.6871365431313203, val_Accuracy : 0.5327102803738317
#
# Train Finished - Train_Loss: 1.4064, Train_Accuracy: 0.5548
# Epoch : 18, val_Loss: 1.6719885941977812, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.3945, Train_Accuracy: 0.5641
# Epoch : 19, val_Loss: 1.6996975747224325, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.3835, Train_Accuracy: 0.5711
# Epoch : 20, val_Loss: 1.7531593269276842, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.3707, Train_Accuracy: 0.5594
# Epoch : 21, val_Loss: 1.5063572375573844, val_Accuracy : 0.5420560747663551
#
# Train Finished - Train_Loss: 1.3585, Train_Accuracy: 0.5653
# Epoch : 22, val_Loss: 1.6898486413688303, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.3396, Train_Accuracy: 0.5641
# Epoch : 23, val_Loss: 1.61890963973286, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.3304, Train_Accuracy: 0.5816
# Epoch : 24, val_Loss: 1.7260400112544265, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.3171, Train_Accuracy: 0.5862
# Epoch : 25, val_Loss: 1.6549732974756544, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.3068, Train_Accuracy: 0.5956
# Epoch : 26, val_Loss: 1.6655416934289664, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.2954, Train_Accuracy: 0.5699
# Epoch : 27, val_Loss: 1.6878077070289683, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.2854, Train_Accuracy: 0.5804
# Epoch : 28, val_Loss: 1.6747107015591916, val_Accuracy : 0.5514018691588785
#
# Train Finished - Train_Loss: 1.2696, Train_Accuracy: 0.5874
# Epoch : 29, val_Loss: 1.6459235253735123, val_Accuracy : 0.5327102803738317
#
# Train Finished - Train_Loss: 1.2562, Train_Accuracy: 0.6049
# Epoch : 30, val_Loss: 1.6799966241711768, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.2520, Train_Accuracy: 0.5991
# Epoch : 31, val_Loss: 1.6187205359200452, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 1.2402, Train_Accuracy: 0.6084
# Epoch : 32, val_Loss: 1.67163540492548, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 1.2224, Train_Accuracy: 0.6107
# Epoch : 33, val_Loss: 1.6493187931096442, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.2137, Train_Accuracy: 0.6200
# Epoch : 34, val_Loss: 1.6622913752760842, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 1.2029, Train_Accuracy: 0.6305
# Epoch : 35, val_Loss: 1.6158127116265697, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 1.2041, Train_Accuracy: 0.6235
# Epoch : 36, val_Loss: 1.6538163390115044, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.1825, Train_Accuracy: 0.6480
# Epoch : 37, val_Loss: 1.6286673946915387, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.1669, Train_Accuracy: 0.6364
# Epoch : 38, val_Loss: 1.6212686378265095, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 1.1538, Train_Accuracy: 0.6492
# Epoch : 39, val_Loss: 1.6460982260302963, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 1.1436, Train_Accuracy: 0.6492
# Epoch : 40, val_Loss: 1.6219126977653147, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 1.1288, Train_Accuracy: 0.6713
# Epoch : 41, val_Loss: 1.6482906519809617, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.1154, Train_Accuracy: 0.6888
# Epoch : 42, val_Loss: 1.6159838293200341, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.1063, Train_Accuracy: 0.6888
# Epoch : 43, val_Loss: 1.5468493220962096, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.0865, Train_Accuracy: 0.6935
# Epoch : 44, val_Loss: 1.5661233919803228, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.0745, Train_Accuracy: 0.7063
# Epoch : 45, val_Loss: 1.7170352846662575, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 1.0668, Train_Accuracy: 0.7238
# Epoch : 46, val_Loss: 1.6037219216890424, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 1.0547, Train_Accuracy: 0.7203
# Epoch : 47, val_Loss: 1.6662026432073005, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.0345, Train_Accuracy: 0.7529
# Epoch : 48, val_Loss: 1.5692452671371888, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 1.0277, Train_Accuracy: 0.7529
# Epoch : 49, val_Loss: 1.5655142525646175, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 1.0255, Train_Accuracy: 0.7471
# Epoch : 50, val_Loss: 1.6529860630213657, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 1.0015, Train_Accuracy: 0.7844
# Epoch : 51, val_Loss: 1.6425452054103957, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.9880, Train_Accuracy: 0.7832
# Epoch : 52, val_Loss: 1.6299006381881571, val_Accuracy : 0.5420560747663551
#
# Train Finished - Train_Loss: 0.9760, Train_Accuracy: 0.7832
# Epoch : 53, val_Loss: 1.643399354453399, val_Accuracy : 0.5700934579439252
#
# Train Finished - Train_Loss: 0.9646, Train_Accuracy: 0.8147
# Epoch : 54, val_Loss: 1.693316816169525, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 0.9468, Train_Accuracy: 0.8089
# Epoch : 55, val_Loss: 1.6535921988086166, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 0.9366, Train_Accuracy: 0.8193
# Epoch : 56, val_Loss: 1.6771318801095552, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.9214, Train_Accuracy: 0.8333
# Epoch : 57, val_Loss: 1.4754435548158449, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 0.9058, Train_Accuracy: 0.8380
# Epoch : 58, val_Loss: 1.6120246726775838, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.8894, Train_Accuracy: 0.8427
# Epoch : 59, val_Loss: 1.635170072038597, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.8798, Train_Accuracy: 0.8485
# Epoch : 60, val_Loss: 1.674705309288524, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.8699, Train_Accuracy: 0.8601
# Epoch : 61, val_Loss: 1.5815639094771625, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.8572, Train_Accuracy: 0.8695
# Epoch : 62, val_Loss: 1.631998071046633, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.8448, Train_Accuracy: 0.8625
# Epoch : 63, val_Loss: 1.7051587505875347, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 0.8300, Train_Accuracy: 0.8683
# Epoch : 64, val_Loss: 1.6293666696994105, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.8165, Train_Accuracy: 0.8776
# Epoch : 65, val_Loss: 1.7095949761221343, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.8060, Train_Accuracy: 0.8753
# Epoch : 66, val_Loss: 1.6785428234349902, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.7972, Train_Accuracy: 0.8788
# Epoch : 67, val_Loss: 1.6723964370299722, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.7907, Train_Accuracy: 0.8811
# Epoch : 68, val_Loss: 1.6855525301995677, val_Accuracy : 0.5233644859813084
#
# Train Finished - Train_Loss: 0.7735, Train_Accuracy: 0.8800
# Epoch : 69, val_Loss: 1.6437054215190567, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.7690, Train_Accuracy: 0.8916
# Epoch : 70, val_Loss: 1.6855298782063421, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.7551, Train_Accuracy: 0.8893
# Epoch : 71, val_Loss: 1.6463008729096884, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.7481, Train_Accuracy: 0.8974
# Epoch : 72, val_Loss: 1.6803767302325954, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.7303, Train_Accuracy: 0.8998
# Epoch : 73, val_Loss: 1.722982540308872, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.7259, Train_Accuracy: 0.8998
# Epoch : 74, val_Loss: 1.614450895897696, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.7204, Train_Accuracy: 0.8974
# Epoch : 75, val_Loss: 1.7401045727952618, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.7068, Train_Accuracy: 0.9033
# Epoch : 76, val_Loss: 1.622446742013236, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.6975, Train_Accuracy: 0.9056
# Epoch : 77, val_Loss: 1.6868846305062837, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.6822, Train_Accuracy: 0.9138
# Epoch : 78, val_Loss: 1.6822243717229255, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.6801, Train_Accuracy: 0.9114
# Epoch : 79, val_Loss: 1.7411030074146305, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.6678, Train_Accuracy: 0.9184
# Epoch : 80, val_Loss: 1.6922238519258588, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.6510, Train_Accuracy: 0.9231
# Epoch : 81, val_Loss: 1.8019380524893787, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.6473, Train_Accuracy: 0.9231
# Epoch : 82, val_Loss: 1.7809270832026116, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.6423, Train_Accuracy: 0.9242
# Epoch : 83, val_Loss: 1.7583604260025738, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.6335, Train_Accuracy: 0.9231
# Epoch : 84, val_Loss: 1.7036783494681955, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.6180, Train_Accuracy: 0.9336
# Epoch : 85, val_Loss: 1.7154677872345827, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.6062, Train_Accuracy: 0.9324
# Epoch : 86, val_Loss: 1.68467400452801, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.6043, Train_Accuracy: 0.9406
# Epoch : 87, val_Loss: 1.6051472904526185, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.5951, Train_Accuracy: 0.9347
# Epoch : 88, val_Loss: 1.753090876285161, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.5832, Train_Accuracy: 0.9336
# Epoch : 89, val_Loss: 1.7326450659849932, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.5789, Train_Accuracy: 0.9371
# Epoch : 90, val_Loss: 1.828048857573037, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.5678, Train_Accuracy: 0.9476
# Epoch : 91, val_Loss: 1.7177773324128622, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.5756, Train_Accuracy: 0.9371
# Epoch : 92, val_Loss: 1.6442750012763192, val_Accuracy : 0.5327102803738317
#
# Train Finished - Train_Loss: 0.5549, Train_Accuracy: 0.9476
# Epoch : 93, val_Loss: 1.884150184203531, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.5533, Train_Accuracy: 0.9452
# Epoch : 94, val_Loss: 1.847135410130581, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.5392, Train_Accuracy: 0.9510
# Epoch : 95, val_Loss: 1.7485691364680496, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.5393, Train_Accuracy: 0.9417
# Epoch : 96, val_Loss: 1.7119740860484471, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.5241, Train_Accuracy: 0.9522
# Epoch : 97, val_Loss: 1.7388957683171067, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.5168, Train_Accuracy: 0.9510
# Epoch : 98, val_Loss: 1.8144499876788844, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.5075, Train_Accuracy: 0.9534
# Epoch : 99, val_Loss: 1.8062900427345918, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.4876, Train_Accuracy: 0.9580
# Epoch : 100, val_Loss: 1.7873492820240626, val_Accuracy : 0.4672897196261682

# %%
# 학습 실행2
for epoch in range(100):
    train(model, train_loader, optimizer)
    val_loss, val_accuracy, val_predict_history, val_label_history = evaluate(model, test_loader)
    print(f"Epoch : {epoch + 1}, val_Loss: {val_loss}, val_Accuracy : {val_accuracy}", '\n')
# Out:
# Train Finished - Train_Loss: 0.4921, Train_Accuracy: 0.9592
# Epoch : 1, val_Loss: 1.86459270815983, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.4745, Train_Accuracy: 0.9627
# Epoch : 2, val_Loss: 1.7551933805519175, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.4730, Train_Accuracy: 0.9627
# Epoch : 3, val_Loss: 1.767430737753895, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.4636, Train_Accuracy: 0.9627
# Epoch : 4, val_Loss: 1.791562686456698, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.4552, Train_Accuracy: 0.9627
# Epoch : 5, val_Loss: 1.8748944273618895, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.4509, Train_Accuracy: 0.9639
# Epoch : 6, val_Loss: 1.7921829446453914, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.4415, Train_Accuracy: 0.9685
# Epoch : 7, val_Loss: 1.830057264488434, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.4332, Train_Accuracy: 0.9650
# Epoch : 8, val_Loss: 1.822445682276075, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.4231, Train_Accuracy: 0.9674
# Epoch : 9, val_Loss: 1.7447685081268025, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.4180, Train_Accuracy: 0.9709
# Epoch : 10, val_Loss: 1.735462736860614, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.4191, Train_Accuracy: 0.9674
# Epoch : 11, val_Loss: 1.7155467238381645, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.4243, Train_Accuracy: 0.9615
# Epoch : 12, val_Loss: 1.9352373497508397, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.4087, Train_Accuracy: 0.9685
# Epoch : 13, val_Loss: 1.7684699664606112, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.4014, Train_Accuracy: 0.9720
# Epoch : 14, val_Loss: 1.897580191353771, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 0.3837, Train_Accuracy: 0.9755
# Epoch : 15, val_Loss: 1.8447587155850134, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.3823, Train_Accuracy: 0.9790
# Epoch : 16, val_Loss: 1.9810643240670178, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.3768, Train_Accuracy: 0.9802
# Epoch : 17, val_Loss: 1.8575294886794045, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 0.3653, Train_Accuracy: 0.9790
# Epoch : 18, val_Loss: 1.9334932888779686, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.3631, Train_Accuracy: 0.9802
# Epoch : 19, val_Loss: 2.0330210979853836, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.3506, Train_Accuracy: 0.9802
# Epoch : 20, val_Loss: 1.8015984864992516, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.3509, Train_Accuracy: 0.9814
# Epoch : 21, val_Loss: 1.9277850356057427, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.3481, Train_Accuracy: 0.9814
# Epoch : 22, val_Loss: 1.817926585117233, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.3654, Train_Accuracy: 0.9685
# Epoch : 23, val_Loss: 1.849986459607276, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.3380, Train_Accuracy: 0.9790
# Epoch : 24, val_Loss: 1.7907908475287606, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.3295, Train_Accuracy: 0.9790
# Epoch : 25, val_Loss: 1.8191155317787813, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.3225, Train_Accuracy: 0.9790
# Epoch : 26, val_Loss: 1.817800321311594, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.3126, Train_Accuracy: 0.9814
# Epoch : 27, val_Loss: 1.8517706928966202, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.3053, Train_Accuracy: 0.9814
# Epoch : 28, val_Loss: 1.974611750272947, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.3068, Train_Accuracy: 0.9848
# Epoch : 29, val_Loss: 2.0138289505076186, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.2981, Train_Accuracy: 0.9837
# Epoch : 30, val_Loss: 2.076087345586759, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.2980, Train_Accuracy: 0.9860
# Epoch : 31, val_Loss: 1.9676839213504969, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2956, Train_Accuracy: 0.9883
# Epoch : 32, val_Loss: 1.8507628908781248, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2895, Train_Accuracy: 0.9883
# Epoch : 33, val_Loss: 2.050222873687744, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.2862, Train_Accuracy: 0.9872
# Epoch : 34, val_Loss: 1.9390157271768445, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2831, Train_Accuracy: 0.9883
# Epoch : 35, val_Loss: 2.0133363465282406, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2770, Train_Accuracy: 0.9907
# Epoch : 36, val_Loss: 2.0140307863182, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2674, Train_Accuracy: 0.9907
# Epoch : 37, val_Loss: 1.974989427584354, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.2696, Train_Accuracy: 0.9942
# Epoch : 38, val_Loss: 2.058816116546916, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2659, Train_Accuracy: 0.9942
# Epoch : 39, val_Loss: 2.0676917806964052, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.2608, Train_Accuracy: 0.9930
# Epoch : 40, val_Loss: 2.117534753318145, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2484, Train_Accuracy: 0.9930
# Epoch : 41, val_Loss: 2.19295275768387, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2494, Train_Accuracy: 0.9953
# Epoch : 42, val_Loss: 1.9745737904700162, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2488, Train_Accuracy: 0.9977
# Epoch : 43, val_Loss: 2.1389982098730926, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.2376, Train_Accuracy: 0.9977
# Epoch : 44, val_Loss: 2.0242960686995604, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.2421, Train_Accuracy: 0.9942
# Epoch : 45, val_Loss: 1.9362483804471025, val_Accuracy : 0.514018691588785
#
# Train Finished - Train_Loss: 0.2315, Train_Accuracy: 0.9953
# Epoch : 46, val_Loss: 1.889703692676865, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.2303, Train_Accuracy: 0.9988
# Epoch : 47, val_Loss: 2.298555418709728, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2293, Train_Accuracy: 0.9988
# Epoch : 48, val_Loss: 2.236978856202598, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2175, Train_Accuracy: 0.9977
# Epoch : 49, val_Loss: 2.1906945237489506, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.2147, Train_Accuracy: 0.9977
# Epoch : 50, val_Loss: 2.3602935220593606, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2102, Train_Accuracy: 0.9965
# Epoch : 51, val_Loss: 2.2346932598363574, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2112, Train_Accuracy: 0.9988
# Epoch : 52, val_Loss: 2.2249426173272533, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.2132, Train_Accuracy: 0.9988
# Epoch : 53, val_Loss: 2.1291884529256375, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.2093, Train_Accuracy: 0.9977
# Epoch : 54, val_Loss: 2.1991555311969506, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.1993, Train_Accuracy: 0.9977
# Epoch : 55, val_Loss: 2.164895913311254, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2011, Train_Accuracy: 0.9988
# Epoch : 56, val_Loss: 2.1682770853844757, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1986, Train_Accuracy: 0.9988
# Epoch : 57, val_Loss: 2.12685168346512, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.1966, Train_Accuracy: 0.9988
# Epoch : 58, val_Loss: 2.3077861883929955, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1939, Train_Accuracy: 0.9977
# Epoch : 59, val_Loss: 2.213653949933631, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1900, Train_Accuracy: 0.9988
# Epoch : 60, val_Loss: 2.2893031913543416, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1827, Train_Accuracy: 0.9988
# Epoch : 61, val_Loss: 2.1489784784406143, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.1851, Train_Accuracy: 0.9965
# Epoch : 62, val_Loss: 2.511280398502528, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.2391, Train_Accuracy: 0.9720
# Epoch : 63, val_Loss: 2.0284842107897605, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.2111, Train_Accuracy: 0.9825
# Epoch : 64, val_Loss: 2.4334851425384807, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.2958, Train_Accuracy: 0.9557
# Epoch : 65, val_Loss: 2.3333901111210618, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.2173, Train_Accuracy: 0.9814
# Epoch : 66, val_Loss: 2.1172721764751685, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1951, Train_Accuracy: 0.9930
# Epoch : 67, val_Loss: 2.20626091288629, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1830, Train_Accuracy: 0.9965
# Epoch : 68, val_Loss: 2.3607449665247837, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1773, Train_Accuracy: 0.9977
# Epoch : 69, val_Loss: 2.5075388222097237, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1740, Train_Accuracy: 0.9988
# Epoch : 70, val_Loss: 2.4391949644712643, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1701, Train_Accuracy: 0.9988
# Epoch : 71, val_Loss: 2.386561153091003, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1676, Train_Accuracy: 0.9988
# Epoch : 72, val_Loss: 2.4896818254595603, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.1577, Train_Accuracy: 1.0000
# Epoch : 73, val_Loss: 2.643802464565384, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1608, Train_Accuracy: 1.0000
# Epoch : 74, val_Loss: 2.3720384112028317, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.1502, Train_Accuracy: 1.0000
# Epoch : 75, val_Loss: 2.193193999406333, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1569, Train_Accuracy: 1.0000
# Epoch : 76, val_Loss: 2.4223418993370553, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1546, Train_Accuracy: 1.0000
# Epoch : 77, val_Loss: 2.444191175086476, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1530, Train_Accuracy: 1.0000
# Epoch : 78, val_Loss: 2.69072441742799, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1523, Train_Accuracy: 1.0000
# Epoch : 79, val_Loss: 2.257872066765188, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.1473, Train_Accuracy: 1.0000
# Epoch : 80, val_Loss: 2.4515846600042326, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1465, Train_Accuracy: 1.0000
# Epoch : 81, val_Loss: 2.7200703754603306, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1444, Train_Accuracy: 1.0000
# Epoch : 82, val_Loss: 2.5854204703714245, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1423, Train_Accuracy: 1.0000
# Epoch : 83, val_Loss: 2.5928605338123356, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1413, Train_Accuracy: 1.0000
# Epoch : 84, val_Loss: 2.5967998682895552, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1398, Train_Accuracy: 1.0000
# Epoch : 85, val_Loss: 2.282863511103336, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1385, Train_Accuracy: 1.0000
# Epoch : 86, val_Loss: 2.7888596704073043, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1340, Train_Accuracy: 1.0000
# Epoch : 87, val_Loss: 2.8327801962879215, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1285, Train_Accuracy: 1.0000
# Epoch : 88, val_Loss: 2.502754425334039, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1325, Train_Accuracy: 1.0000
# Epoch : 89, val_Loss: 2.601749366688951, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1294, Train_Accuracy: 1.0000
# Epoch : 90, val_Loss: 2.85418043403982, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1215, Train_Accuracy: 1.0000
# Epoch : 91, val_Loss: 2.5649151946896707, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1273, Train_Accuracy: 1.0000
# Epoch : 92, val_Loss: 2.5580670410227553, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1252, Train_Accuracy: 1.0000
# Epoch : 93, val_Loss: 2.8124227969445914, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1257, Train_Accuracy: 1.0000
# Epoch : 94, val_Loss: 2.5233359114031924, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.1216, Train_Accuracy: 1.0000
# Epoch : 95, val_Loss: 2.8883231956268025, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.1220, Train_Accuracy: 1.0000
# Epoch : 96, val_Loss: 2.7018932182098103, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1195, Train_Accuracy: 1.0000
# Epoch : 97, val_Loss: 2.7824182332119096, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1195, Train_Accuracy: 1.0000
# Epoch : 98, val_Loss: 2.6292669929076578, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1167, Train_Accuracy: 1.0000
# Epoch : 99, val_Loss: 2.9223421979173323, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.1158, Train_Accuracy: 1.0000
# Epoch : 100, val_Loss: 2.7622831201998985, val_Accuracy : 0.4766355140186916

# %%
# 학습 실행3
for epoch in range(100):
    train(model, train_loader, optimizer)
    val_loss, val_accuracy, val_predict_history, val_label_history = evaluate(model, test_loader)
    print(f"Epoch : {epoch + 1}, val_Loss: {val_loss}, val_Accuracy : {val_accuracy}", '\n')
# Out:
# Train Finished - Train_Loss: 0.1095, Train_Accuracy: 1.0000
# Epoch : 1, val_Loss: 2.7573465186858845, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.1131, Train_Accuracy: 1.0000
# Epoch : 2, val_Loss: 2.5060153453149527, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1052, Train_Accuracy: 1.0000
# Epoch : 3, val_Loss: 2.981754329717048, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.1107, Train_Accuracy: 1.0000
# Epoch : 4, val_Loss: 2.8046650218072338, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.1072, Train_Accuracy: 1.0000
# Epoch : 5, val_Loss: 2.81454728919769, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.1079, Train_Accuracy: 1.0000
# Epoch : 6, val_Loss: 2.8358022119397317, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.1059, Train_Accuracy: 1.0000
# Epoch : 7, val_Loss: 2.9009566886402736, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.0986, Train_Accuracy: 1.0000
# Epoch : 8, val_Loss: 2.9492233490275446, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1047, Train_Accuracy: 1.0000
# Epoch : 9, val_Loss: 2.744235479943106, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 0.1031, Train_Accuracy: 1.0000
# Epoch : 10, val_Loss: 2.7743469487840886, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.1000, Train_Accuracy: 1.0000
# Epoch : 11, val_Loss: 2.9097415710164007, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0945, Train_Accuracy: 1.0000
# Epoch : 12, val_Loss: 2.6907711207309615, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0993, Train_Accuracy: 1.0000
# Epoch : 13, val_Loss: 2.9670763283132393, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.0993, Train_Accuracy: 1.0000
# Epoch : 14, val_Loss: 3.014827496537538, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0976, Train_Accuracy: 1.0000
# Epoch : 15, val_Loss: 2.929400711416084, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0891, Train_Accuracy: 1.0000
# Epoch : 16, val_Loss: 3.042363523322845, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0946, Train_Accuracy: 1.0000
# Epoch : 17, val_Loss: 3.2560911178588867, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.0936, Train_Accuracy: 1.0000
# Epoch : 18, val_Loss: 3.057926272677484, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0947, Train_Accuracy: 1.0000
# Epoch : 19, val_Loss: 2.7646562986284775, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0923, Train_Accuracy: 1.0000
# Epoch : 20, val_Loss: 2.686900189546781, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0854, Train_Accuracy: 1.0000
# Epoch : 21, val_Loss: 2.9785588968580012, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.0890, Train_Accuracy: 1.0000
# Epoch : 22, val_Loss: 3.2882239573469785, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0886, Train_Accuracy: 1.0000
# Epoch : 23, val_Loss: 2.8820425907028056, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0870, Train_Accuracy: 1.0000
# Epoch : 24, val_Loss: 2.8871316419583617, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0865, Train_Accuracy: 1.0000
# Epoch : 25, val_Loss: 3.2055577073141794, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0865, Train_Accuracy: 1.0000
# Epoch : 26, val_Loss: 2.9070620224854657, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0874, Train_Accuracy: 1.0000
# Epoch : 27, val_Loss: 2.7789015282537335, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0858, Train_Accuracy: 1.0000
# Epoch : 28, val_Loss: 3.0776779763052398, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.0829, Train_Accuracy: 1.0000
# Epoch : 29, val_Loss: 3.1190176990544685, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0815, Train_Accuracy: 1.0000
# Epoch : 30, val_Loss: 3.2882102092849874, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0808, Train_Accuracy: 1.0000
# Epoch : 31, val_Loss: 3.027957331354373, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0800, Train_Accuracy: 1.0000
# Epoch : 32, val_Loss: 3.1812393241953627, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0798, Train_Accuracy: 1.0000
# Epoch : 33, val_Loss: 3.155300996013891, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0789, Train_Accuracy: 1.0000
# Epoch : 34, val_Loss: 3.344097021584199, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.0781, Train_Accuracy: 1.0000
# Epoch : 35, val_Loss: 3.3606087158773548, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0781, Train_Accuracy: 1.0000
# Epoch : 36, val_Loss: 3.2917094186087636, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0778, Train_Accuracy: 1.0000
# Epoch : 37, val_Loss: 3.098139887658235, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0766, Train_Accuracy: 1.0000
# Epoch : 38, val_Loss: 3.0860266150715194, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0633, Train_Accuracy: 1.0000
# Epoch : 39, val_Loss: 3.0630604814146167, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0687, Train_Accuracy: 1.0000
# Epoch : 40, val_Loss: 3.115360670000593, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.0730, Train_Accuracy: 1.0000
# Epoch : 41, val_Loss: 3.3271235171879563, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0729, Train_Accuracy: 1.0000
# Epoch : 42, val_Loss: 3.2834374436708256, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0733, Train_Accuracy: 1.0000
# Epoch : 43, val_Loss: 2.8858460399592034, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0725, Train_Accuracy: 1.0000
# Epoch : 44, val_Loss: 3.224394602196239, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0706, Train_Accuracy: 1.0000
# Epoch : 45, val_Loss: 3.2833943389286504, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0690, Train_Accuracy: 1.0000
# Epoch : 46, val_Loss: 3.5486748953846012, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0699, Train_Accuracy: 1.0000
# Epoch : 47, val_Loss: 3.4853947363167164, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0633, Train_Accuracy: 1.0000
# Epoch : 48, val_Loss: 3.3417836795343416, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0694, Train_Accuracy: 1.0000
# Epoch : 49, val_Loss: 3.3880171552996767, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0671, Train_Accuracy: 1.0000
# Epoch : 50, val_Loss: 3.3020458912180963, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.0678, Train_Accuracy: 1.0000
# Epoch : 51, val_Loss: 3.18637573384793, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0652, Train_Accuracy: 1.0000
# Epoch : 52, val_Loss: 3.1161244294353736, val_Accuracy : 0.5046728971962616
#
# Train Finished - Train_Loss: 0.0659, Train_Accuracy: 1.0000
# Epoch : 53, val_Loss: 3.193371665811984, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0659, Train_Accuracy: 1.0000
# Epoch : 54, val_Loss: 3.4666383355577417, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.0586, Train_Accuracy: 1.0000
# Epoch : 55, val_Loss: 3.51420803604839, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 0.0594, Train_Accuracy: 1.0000
# Epoch : 56, val_Loss: 3.4041591938410964, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0616, Train_Accuracy: 1.0000
# Epoch : 57, val_Loss: 3.526663717822494, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 0.0624, Train_Accuracy: 1.0000
# Epoch : 58, val_Loss: 3.3612611093253735, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0524, Train_Accuracy: 1.0000
# Epoch : 59, val_Loss: 3.4333195909161436, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0628, Train_Accuracy: 1.0000
# Epoch : 60, val_Loss: 3.5432765818087852, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0615, Train_Accuracy: 1.0000
# Epoch : 61, val_Loss: 3.4433984578212846, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0595, Train_Accuracy: 1.0000
# Epoch : 62, val_Loss: 3.420381430153535, val_Accuracy : 0.4953271028037383
#
# Train Finished - Train_Loss: 0.0604, Train_Accuracy: 1.0000
# Epoch : 63, val_Loss: 3.376053596211371, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0608, Train_Accuracy: 1.0000
# Epoch : 64, val_Loss: 3.6158651102369075, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0580, Train_Accuracy: 1.0000
# Epoch : 65, val_Loss: 3.455023212967632, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0598, Train_Accuracy: 1.0000
# Epoch : 66, val_Loss: 3.2456291323510285, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0530, Train_Accuracy: 1.0000
# Epoch : 67, val_Loss: 3.745259329537365, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0478, Train_Accuracy: 1.0000
# Epoch : 68, val_Loss: 3.443949320605982, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0578, Train_Accuracy: 1.0000
# Epoch : 69, val_Loss: 3.7279238478045595, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0575, Train_Accuracy: 1.0000
# Epoch : 70, val_Loss: 3.509286051598665, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.1867, Train_Accuracy: 0.9510
# Epoch : 71, val_Loss: 3.512609980930792, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 0.1433, Train_Accuracy: 0.9662
# Epoch : 72, val_Loss: 3.2448350870720692, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0819, Train_Accuracy: 0.9848
# Epoch : 73, val_Loss: 2.9238556567753586, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0679, Train_Accuracy: 0.9930
# Epoch : 74, val_Loss: 3.0738200651151, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0579, Train_Accuracy: 1.0000
# Epoch : 75, val_Loss: 3.1924944726106164, val_Accuracy : 0.48598130841121495
#
# Train Finished - Train_Loss: 0.0564, Train_Accuracy: 1.0000
# Epoch : 76, val_Loss: 2.897162767214196, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0550, Train_Accuracy: 1.0000
# Epoch : 77, val_Loss: 2.8950459979404912, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0547, Train_Accuracy: 1.0000
# Epoch : 78, val_Loss: 3.1914985781518097, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0501, Train_Accuracy: 1.0000
# Epoch : 79, val_Loss: 3.291903335357381, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0540, Train_Accuracy: 1.0000
# Epoch : 80, val_Loss: 3.196997990118009, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0544, Train_Accuracy: 1.0000
# Epoch : 81, val_Loss: 3.1406820110071485, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0489, Train_Accuracy: 1.0000
# Epoch : 82, val_Loss: 3.399562808954827, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0524, Train_Accuracy: 1.0000
# Epoch : 83, val_Loss: 3.156913083290385, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0480, Train_Accuracy: 1.0000
# Epoch : 84, val_Loss: 3.061343406962457, val_Accuracy : 0.45794392523364486
#
# Train Finished - Train_Loss: 0.0525, Train_Accuracy: 1.0000
# Epoch : 85, val_Loss: 3.3143380334444137, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0523, Train_Accuracy: 1.0000
# Epoch : 86, val_Loss: 3.257254128144166, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0518, Train_Accuracy: 1.0000
# Epoch : 87, val_Loss: 3.3517156939640222, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0519, Train_Accuracy: 1.0000
# Epoch : 88, val_Loss: 3.37774155518719, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0499, Train_Accuracy: 1.0000
# Epoch : 89, val_Loss: 3.257136115403933, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0504, Train_Accuracy: 1.0000
# Epoch : 90, val_Loss: 3.326947328086211, val_Accuracy : 0.4672897196261682
#
# Train Finished - Train_Loss: 0.0457, Train_Accuracy: 1.0000
# Epoch : 91, val_Loss: 3.3476243954952634, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0492, Train_Accuracy: 1.0000
# Epoch : 92, val_Loss: 3.214715921990225, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0491, Train_Accuracy: 1.0000
# Epoch : 93, val_Loss: 3.086844979045547, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0443, Train_Accuracy: 1.0000
# Epoch : 94, val_Loss: 3.2364662696267956, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0487, Train_Accuracy: 1.0000
# Epoch : 95, val_Loss: 3.217465502775718, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0425, Train_Accuracy: 1.0000
# Epoch : 96, val_Loss: 3.2970551909687362, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0432, Train_Accuracy: 1.0000
# Epoch : 97, val_Loss: 3.3109877666580343, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0471, Train_Accuracy: 1.0000
# Epoch : 98, val_Loss: 3.861795180311827, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0471, Train_Accuracy: 1.0000
# Epoch : 99, val_Loss: 3.457087882211275, val_Accuracy : 0.4766355140186916
#
# Train Finished - Train_Loss: 0.0420, Train_Accuracy: 1.0000
# Epoch : 100, val_Loss: 3.065208301644459, val_Accuracy : 0.4766355140186916
