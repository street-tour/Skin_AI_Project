# %%
import os
import json
import OpenCV
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import os
#       2 import json
# ----> 3 import OpenCV
#
# ModuleNotFoundError: No module named 'OpenCV'

# %%
base_dir = r"E:\Data\028.한국인 피부상태 측정 데이터\3.개방데이터\1.데이터\Training\02.라벨링데이터\TL\1. 디지털카메라\0002"

# %%
image_path = r"E:\Data\028.한국인 피부상태 측정 데이터\3.개방데이터\1.데이터\Training\01.원천데이터\TS\1. 디지털카메라\0002\0002_01_F.jpg"

# %%
json_file_names = [
    "0002_01_F_00.json",
    "0002_01_F_01.json",
    "0002_01_F_02.json",
    "0002_01_F_03.json",
    "0002_01_F_04.json",
    "0002_01_F_05.json",
    "0002_01_F_06.json",
    "0002_01_F_07.json",
    "0002_01_F_08.json",
]

# %%
data = {}

# %%
for file_name in json_file_names:
    file_path = os.path.join(base_dir, file_name)
    with open(file_path, 'r', encoding='utf-8') as f:
        data[file_name] = json.load(f)

# %%
data
# Out:
# {'0002_01_F_00.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 0,
#    'bbox': [0, 0, 2136, 3216]},
#   'annotations': {'acne': None},
#   'equipment': {'pigmentation_count': 158}},
#  '0002_01_F_01.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 1,
#    'bbox': [564, 710, 1676, 1246]},
#   'annotations': {'forehead_pigmentation': 1, 'forehead_wrinkle': 1},
#   'equipment': {'forehead_moisture': 75.0,
#    'forehead_elasticity_R0': 0.287,
#    'forehead_elasticity_R1': 0.097,
#    'forehead_elasticity_R2': 0.662,
#    'forehead_elasticity_R3': 0.329,
#    'forehead_elasticity_R4': 0.135,
#    'forehead_elasticity_R5': 0.552,
#    'forehead_elasticity_R6': 0.649,
#    'forehead_elasticity_R7': 0.335,
#    'forehead_elasticity_R8': 0.19,
#    'forehead_elasticity_R9': 0.042,
#    'forehead_elasticity_Q0': 57.4,
#    'forehead_elasticity_Q1': 0.579,
#    'forehead_elasticity_Q2': 0.438,
#    'forehead_elasticity_Q3': 0.142}},
#  '0002_01_F_02.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 2,
#    'bbox': [965, 1238, 1249, 1570]},
#   'annotations': {'glabellus_wrinkle': 1},
#   'equipment': None},
#  '0002_01_F_03.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 3,
#    'bbox': [226, 1458, 464, 1852]},
#   'annotations': {'l_perocular_wrinkle': 3},
#   'equipment': {'l_perocular_wrinkle_Ra': 15.44,
#    'l_perocular_wrinkle_Rmax': 122.92,
#    'l_perocular_wrinkle_Rt': 127.85,
#    'l_perocular_wrinkle_Rz=Rtm': 89.604,
#    'l_perocular_wrinkle_Rp': 58.363,
#    'l_perocular_wrinkle_Rv': 69.486,
#    'l_perocular_wrinkle_Rq': 19.504,
#    'l_perocular_wrinkle_R3z': 49.631}},
#  '0002_01_F_04.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 4,
#    'bbox': [1773, 1411, 1956, 1868]},
#   'annotations': {'r_perocular_wrinkle': 3},
#   'equipment': {'r_perocular_wrinkle_Ra': 14.39,
#    'r_perocular_wrinkle_Rmax': 116.79,
#    'r_perocular_wrinkle_Rt': 122.94,
#    'r_perocular_wrinkle_Rz=Rtm': 84.142,
#    'r_perocular_wrinkle_Rp': 54.029,
#    'r_perocular_wrinkle_Rv': 68.907,
#    'r_perocular_wrinkle_Rq': 18.147,
#    'r_perocular_wrinkle_R3z': 47.082}},
#  '0002_01_F_05.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 5,
#    'bbox': [347, 1717, 865, 2390]},
#   'annotations': {'l_cheek_pore': 2, 'l_cheek_pigmentation': 3},
#   'equipment': {'l_cheek_moisture': 63.0,
#    'l_cheek_elasticity_R0': 0.246,
#    'l_cheek_elasticity_R1': 0.087,
#    'l_cheek_elasticity_R2': 0.646,
#    'l_cheek_elasticity_R3': 0.291,
#    'l_cheek_elasticity_R4': 0.135,
#    'l_cheek_elasticity_R5': 0.659,
#    'l_cheek_elasticity_R6': 0.783,
#    'l_cheek_elasticity_R7': 0.37,
#    'l_cheek_elasticity_R8': 0.159,
#    'l_cheek_elasticity_R9': 0.045,
#    'l_cheek_elasticity_Q0': 49.2,
#    'l_cheek_elasticity_Q1': 0.577,
#    'l_cheek_elasticity_Q2': 0.453,
#    'l_cheek_elasticity_Q3': 0.124,
#    'l_cheek_pore': 631.0}},
#  '0002_01_F_06.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 6,
#    'bbox': [1379, 1710, 1853, 2377]},
#   'annotations': {'r_cheek_pore': 2, 'r_cheek_pigmentation': 3},
#   'equipment': {'r_cheek_moisture': 64.0,
#    'r_cheek_elasticity_R0': 0.278,
#    'r_cheek_elasticity_R1': 0.102,
#    'r_cheek_elasticity_R2': 0.633,
#    'r_cheek_elasticity_R3': 0.315,
#    'r_cheek_elasticity_R4': 0.144,
#    'r_cheek_elasticity_R5': 0.633,
#    'r_cheek_elasticity_R6': 0.727,
#    'r_cheek_elasticity_R7': 0.367,
#    'r_cheek_elasticity_R8': 0.176,
#    'r_cheek_elasticity_R9': 0.037,
#    'r_cheek_elasticity_Q0': 55.6,
#    'r_cheek_elasticity_Q1': 0.563,
#    'r_cheek_elasticity_Q2': 0.449,
#    'r_cheek_elasticity_Q3': 0.114,
#    'r_cheek_pore': 691.0}},
#  '0002_01_F_07.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 7,
#    'bbox': [809, 2428, 1454, 2679]},
#   'annotations': {'lip_dryness': 2},
#   'equipment': None},
#  '0002_01_F_08.json': {'info': {'filename': '0002_01_F.jpg',
#    'id': '0002',
#    'gender': 'F',
#    'age': 50,
#    'date': '2023-07-27',
#    'skin_type': 0,
#    'sensitive': 0},
#   'images': {'device': 0,
#    'width': 2136,
#    'height': 3216,
#    'angle': 0,
#    'facepart': 8,
#    'bbox': [383, 2512, 1811, 2994]},
#   'annotations': {'chin_sagging': 0},
#   'equipment': {'chin_moisture': 66.0,
#    'chin_elasticity_R0': 0.279,
#    'chin_elasticity_R1': 0.088,
#    'chin_elasticity_R2': 0.685,
#    'chin_elasticity_R3': 0.322,
#    'chin_elasticity_R4': 0.152,
#    'chin_elasticity_R5': 0.566,
#    'chin_elasticity_R6': 0.594,
#    'chin_elasticity_R7': 0.355,
#    'chin_elasticity_R8': 0.191,
#    'chin_elasticity_R9': 0.043,
#    'chin_elasticity_Q0': 55.8,
#    'chin_elasticity_Q1': 0.606,
#    'chin_elasticity_Q2': 0.457,
#    'chin_elasticity_Q3': 0.149}}}

# %%
image = Image.open(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 image = Image.open(image_path)
#
# NameError: name 'Image' is not defined
