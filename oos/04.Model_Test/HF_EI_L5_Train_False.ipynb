# %% [markdown]
# base_model 허깅페이스(https://huggingface.co/Anwarkh1/Skin_Cancer-Image_Classification)
# 모델 가중치 업데이트 불가능 상태로 테스트
# 데이터 : 이마(색소침착, 0-5)
# 가중치 : 데이터 분포에 따른 가중치 적용

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset
from torchvision import transforms, models
from transformers import AutoModelForImageClassification

# %%
from transformers import AutoModel, AutoTokenizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def Image_feature_selector(data_sets, enhance):
    import cv2
    import numpy as np
    from PIL import Image  # PIL 추가

    new_image = {}
    file_name = data_sets["Images"].keys()
    for file_key in file_name:

        # 이미지 불러오기
        image = data_sets['Images'][file_key]

        # 어두운 영역을 감지하기 위해 이미지를 그레이스케일로 변환
        gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

        # 이미지의 평균 밝기 계산
        mean_brightness = np.mean(gray_image) + enhance

        # 평균 밝기를 기준으로 어두운 영역 마스크 생성
        _, dark_mask = cv2.threshold(gray_image, mean_brightness - 20, 255, cv2.THRESH_BINARY_INV)

        # 어두운 영역을 강조하기 위해 밝기와 대비 증가
        enhanced_image = image.copy()
        enhanced_image[dark_mask > 0] = cv2.addWeighted(enhanced_image[dark_mask > 0], 1.8, np.zeros_like(enhanced_image[dark_mask > 0]), 0, 60)

        # numpy 배열을 PIL.Image로 변환
        new_image[file_key] = Image.fromarray(cv2.cvtColor(enhanced_image, cv2.COLOR_BGR2RGB))  # OpenCV는 BGR, PIL은 RGB 사용

    return new_image

# %%
# GPU 여부 확인
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(device)
# Out:
# cuda

# %%
# 데이터 준비 1. 핸드폰, 전면, 이마, 메타데이터 전체
# 테스트데이터
path = "/content/drive/MyDrive/Human_Final_Project/Data/Train_Data_Sets_02.pkl"
with open(path, "rb") as pickle_file:
    train_data_sets = pickle.load(pickle_file)
    print("데이터 로드 완료!!")
# Out:
# 데이터 로드 완료!!

# %%
# 검증데이터
path = "/content/drive/MyDrive/Human_Final_Project/Data/Val_Data_Sets_02.pkl"
with open(path, "rb") as pickle_file:
    val_data_sets = pickle.load(pickle_file)
    print("데이터 로드 완료!!")
# Out:
# 데이터 로드 완료!!

# %%
# 이미지 이름 추출
file_name = train_data_sets['Images'].keys()
file_list = []
for file_keys in file_name:
    file_list.append(file_keys)

# %%
#이미지 강조
new_image = Image_feature_selector(train_data_sets, 10)
new_val_image = Image_feature_selector(val_data_sets, 10)

# %%
# 데이터 전처리
transform = transforms.Compose([
    transforms.Resize((224, 224)),  # 모델 입력 크기에 맞추기
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ImageNet 기준 정규화
])

# %%
class CustomDataset(Dataset):
    def __init__(self, data_sets, new_image, transform=transform):
        self.images = new_image
        self.metadata = data_sets['Metadata']
        self.keys = list(self.images.keys())
        self.transform = transform

    def __len__(self):
        return len(self.keys)

    def __getitem__(self, idx):
        key = self.keys[idx]
        image = self.images[key]
        if self.transform:
            image = self.transform(image)

        target = torch.tensor(self.metadata[key]['annotations']['forehead_pigmentation'], dtype=torch.float32)
        return image, target

# %%
#데이터셋 생성 (텐서형태로 변환)
dataset = CustomDataset(train_data_sets, new_image)
val_dataset = CustomDataset(val_data_sets, new_val_image)

# %%
#로더를 이용해 데이터 배치화
train_loader = torch.utils.data.DataLoader(dataset, batch_size=32, shuffle=True)
test_loader = torch.utils.data.DataLoader(val_dataset, batch_size=32, shuffle=True)

# %%
class SkinNet(nn.Module):
    def __init__(self):
        super(SkinNet, self).__init__()
        # 사전 학습된 모델 로드
        self.base_model = AutoModelForImageClassification.from_pretrained(
            "Anwarkh1/Skin_Cancer-Image_Classification",
            ignore_mismatched_sizes=True
        )

        # 사전 학습된 모델의 파라미터 고정
        for param in self.base_model.parameters():
            param.requires_grad = False

        # 사전 학습된 모델의 출력 크기 확인
        num_features = self.base_model.classifier.out_features

        # 사용자 정의 레이어 추가
        self.fc1 = nn.Linear(num_features, 1000)  # 128은 임의로 설정한 크기
        self.fc2 = nn.Linear(1000, 6)  # 최종 클래스 수 (6)

    def forward(self, x):
        # 사전 학습된 모델에서 logits 추출
        outputs = self.base_model(x)
        x = outputs.logits  # logits만 가져옴

        # 사용자 정의 레이어를 통과
        x = self.fc1(x)
        x = nn.ReLU()(x)  # 활성화 함수 추가
        x = self.fc2(x)
        return x  # 최종 로짓 값 반환

# %%
#criterion에 적용할 데이터 분포 기반 가중치 조절

# 클래스별 샘플 수
class_counts = torch.tensor([175, 443, 163, 69, 6, 2], dtype=torch.float)

# 전체 샘플 수
total_samples = class_counts.sum()

# 클래스 가중치 계산
num_classes = len(class_counts)
class_weights = total_samples / (num_classes * class_counts)

print("Class Weights:", class_weights)
# Out:
# Class Weights: tensor([ 0.8171,  0.3228,  0.8773,  2.0725, 23.8333, 71.5000])

# %%
model = SkinNet().to(device)
#print(model)

# %%
from torch.optim.lr_scheduler import ReduceLROnPlateau

criterion = nn.CrossEntropyLoss(weight=class_weights).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# %%
def train(model, train_loader, optimizer):
    loss_total = 0
    correct_total = 0
    model.train()
    for idx, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device).long()

        optimizer.zero_grad()

        output = model(images)
        loss = criterion(output, labels)

        loss.backward()
        optimizer.step()

        # 누적 손실 및 정확도 계산
        loss_total += loss.item()
        predicted_values = output.max(1, keepdim=True)[1]
        correct = predicted_values.eq(labels.view_as(predicted_values)).sum().item()
        correct_total += correct



        # 에폭 종료 후 평균 손실 및 정확도 계산
    loss_total /= len(train_loader)  # 배치 개수로 나누어 평균 계산
    accuracy = correct_total / len(train_loader.dataset)  # 전체 데이터셋에서 정확도 계산

    # 마지막 배치 후 결과 출력
    print(f"Train Finished - Train_Loss: {loss_total:.4f}, Train_Accuracy: {accuracy:.4f}")

    return loss_total, accuracy

# %%
def evaluate(model, test_loader):
    loss_total = 0
    correct_total = 0
    predict_history = []
    label_history = []
    total_count = 0
    batch_size = test_loader.batch_size  # DataLoader의 배치 크기 확인
    model.eval()  # evaluation mode로 설정 -> batch-normalization, drop-out 수행 중지
    with torch.no_grad():  # 가중치 업데이트 수행 중지
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device).long()
            output = model(images)
            loss = criterion(output, labels).item()
            loss_total += loss
            predicted_values = output.max(1, keepdim=True)[1]
            correct = predicted_values.eq(labels.view_as(predicted_values)).sum().item()
            correct_total += correct
            total_count += len(predicted_values)

            predict_history.append(predicted_values)
            label_history.append(labels)

    loss_total /= (total_count / batch_size)  # 배치 크기를 변수로 대체
    accuracy = correct_total / total_count

    return loss_total, accuracy, predict_history, label_history

# %%
# 학습 실행
for epoch in range(100):
    train(model, train_loader, optimizer)
    val_loss, val_accuracy, val_predict_history, val_label_history = evaluate(model, test_loader)
    print(f"Epoch : {epoch + 1}, val_Loss: {val_loss}, val_Accuracy : {val_accuracy}", '\n')
# Out:
# Train Finished - Train_Loss: 1.8494, Train_Accuracy: 0.2821
# Epoch : 1, val_Loss: 2.4311984409795744, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.6431, Train_Accuracy: 0.3660
# Epoch : 2, val_Loss: 1.856267982554213, val_Accuracy : 0.19626168224299065
#
# Train Finished - Train_Loss: 1.5589, Train_Accuracy: 0.3112
# Epoch : 3, val_Loss: 1.9304872316734814, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.4961, Train_Accuracy: 0.3590
# Epoch : 4, val_Loss: 1.5943128995806257, val_Accuracy : 0.2336448598130841
#
# Train Finished - Train_Loss: 1.4588, Train_Accuracy: 0.2890
# Epoch : 5, val_Loss: 1.5631011713330991, val_Accuracy : 0.24299065420560748
#
# Train Finished - Train_Loss: 1.4698, Train_Accuracy: 0.3182
# Epoch : 6, val_Loss: 1.7435548550614686, val_Accuracy : 0.17757009345794392
#
# Train Finished - Train_Loss: 1.4377, Train_Accuracy: 0.3380
# Epoch : 7, val_Loss: 1.7507685367192063, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 1.4343, Train_Accuracy: 0.3345
# Epoch : 8, val_Loss: 1.556528412293051, val_Accuracy : 0.4392523364485981
#
# Train Finished - Train_Loss: 1.4090, Train_Accuracy: 0.3625
# Epoch : 9, val_Loss: 1.647090876213858, val_Accuracy : 0.205607476635514
#
# Train Finished - Train_Loss: 1.4070, Train_Accuracy: 0.3054
# Epoch : 10, val_Loss: 1.5497260049124744, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 1.3893, Train_Accuracy: 0.3555
# Epoch : 11, val_Loss: 1.6359706415194217, val_Accuracy : 0.21495327102803738
#
# Train Finished - Train_Loss: 1.4182, Train_Accuracy: 0.3613
# Epoch : 12, val_Loss: 1.5255803972761208, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 1.4124, Train_Accuracy: 0.3718
# Epoch : 13, val_Loss: 1.6504432464314398, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.3585, Train_Accuracy: 0.3415
# Epoch : 14, val_Loss: 1.7517858130909572, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 1.3821, Train_Accuracy: 0.3951
# Epoch : 15, val_Loss: 1.7521911692396503, val_Accuracy : 0.42990654205607476
#
# Train Finished - Train_Loss: 1.3330, Train_Accuracy: 0.3660
# Epoch : 16, val_Loss: 1.638099064336759, val_Accuracy : 0.21495327102803738
#
# Train Finished - Train_Loss: 1.3071, Train_Accuracy: 0.3345
# Epoch : 17, val_Loss: 1.8385768426912967, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.3542, Train_Accuracy: 0.3963
# Epoch : 18, val_Loss: 1.7063940529511354, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 1.3136, Train_Accuracy: 0.3590
# Epoch : 19, val_Loss: 1.763113253584532, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.3154, Train_Accuracy: 0.4126
# Epoch : 20, val_Loss: 1.719737578775281, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.3164, Train_Accuracy: 0.3275
# Epoch : 21, val_Loss: 1.9322961468562903, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 1.3166, Train_Accuracy: 0.3485
# Epoch : 22, val_Loss: 2.0509336239823672, val_Accuracy : 0.4485981308411215
#
# Train Finished - Train_Loss: 1.3466, Train_Accuracy: 0.3893
# Epoch : 23, val_Loss: 1.5849069613162603, val_Accuracy : 0.21495327102803738
#
# Train Finished - Train_Loss: 1.3012, Train_Accuracy: 0.2914
# Epoch : 24, val_Loss: 1.9003240995317976, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 1.3687, Train_Accuracy: 0.3939
# Epoch : 25, val_Loss: 1.7954038816077686, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.2825, Train_Accuracy: 0.3438
# Epoch : 26, val_Loss: 2.004335991690092, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 1.3195, Train_Accuracy: 0.3613
# Epoch : 27, val_Loss: 1.9657377795638324, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 1.2565, Train_Accuracy: 0.4289
# Epoch : 28, val_Loss: 1.9367249747303044, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.2609, Train_Accuracy: 0.3974
# Epoch : 29, val_Loss: 1.9849074533052533, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.2507, Train_Accuracy: 0.4138
# Epoch : 30, val_Loss: 1.86498955699885, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.2432, Train_Accuracy: 0.4161
# Epoch : 31, val_Loss: 1.7990418193496276, val_Accuracy : 0.22429906542056074
#
# Train Finished - Train_Loss: 1.2524, Train_Accuracy: 0.3578
# Epoch : 32, val_Loss: 2.1488342641670015, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 1.2336, Train_Accuracy: 0.3823
# Epoch : 33, val_Loss: 2.119335994542202, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.2526, Train_Accuracy: 0.4254
# Epoch : 34, val_Loss: 1.8928033703955534, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.2247, Train_Accuracy: 0.4161
# Epoch : 35, val_Loss: 2.0037556585864484, val_Accuracy : 0.205607476635514
#
# Train Finished - Train_Loss: 1.2215, Train_Accuracy: 0.3823
# Epoch : 36, val_Loss: 1.8406411643340208, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 1.2160, Train_Accuracy: 0.4021
# Epoch : 37, val_Loss: 2.0735128170976016, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.2422, Train_Accuracy: 0.3974
# Epoch : 38, val_Loss: 2.1495748502071774, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.2102, Train_Accuracy: 0.4254
# Epoch : 39, val_Loss: 2.0782308845876534, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.2735, Train_Accuracy: 0.4126
# Epoch : 40, val_Loss: 1.9962604558356454, val_Accuracy : 0.24299065420560748
#
# Train Finished - Train_Loss: 1.2229, Train_Accuracy: 0.3951
# Epoch : 41, val_Loss: 2.036723306245893, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 1.1814, Train_Accuracy: 0.3788
# Epoch : 42, val_Loss: 2.1524920597254673, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.1912, Train_Accuracy: 0.4056
# Epoch : 43, val_Loss: 2.2940701636198524, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.2466, Train_Accuracy: 0.3811
# Epoch : 44, val_Loss: 2.218588321008415, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 1.1879, Train_Accuracy: 0.4336
# Epoch : 45, val_Loss: 1.9973901053455387, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 1.2156, Train_Accuracy: 0.3811
# Epoch : 46, val_Loss: 2.311600729683849, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.2057, Train_Accuracy: 0.3869
# Epoch : 47, val_Loss: 2.523701498441607, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.2005, Train_Accuracy: 0.3811
# Epoch : 48, val_Loss: 2.210182689060675, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 1.1741, Train_Accuracy: 0.4056
# Epoch : 49, val_Loss: 2.124553680419922, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.1806, Train_Accuracy: 0.4254
# Epoch : 50, val_Loss: 1.9787362357166325, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.1766, Train_Accuracy: 0.3974
# Epoch : 51, val_Loss: 2.3078563725836925, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.1643, Train_Accuracy: 0.4126
# Epoch : 52, val_Loss: 2.4399061470388252, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.1809, Train_Accuracy: 0.3939
# Epoch : 53, val_Loss: 2.0283017737843165, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.1893, Train_Accuracy: 0.4522
# Epoch : 54, val_Loss: 2.123769742306148, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.1483, Train_Accuracy: 0.4219
# Epoch : 55, val_Loss: 2.3289986369765807, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.1425, Train_Accuracy: 0.4114
# Epoch : 56, val_Loss: 2.4151001689590026, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.1520, Train_Accuracy: 0.3893
# Epoch : 57, val_Loss: 2.3133581999306365, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.1635, Train_Accuracy: 0.4184
# Epoch : 58, val_Loss: 2.5082099415431514, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.1470, Train_Accuracy: 0.4347
# Epoch : 59, val_Loss: 2.3035475115909754, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.1533, Train_Accuracy: 0.4382
# Epoch : 60, val_Loss: 2.404326037825825, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 1.1204, Train_Accuracy: 0.4464
# Epoch : 61, val_Loss: 2.590437167158751, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 1.1592, Train_Accuracy: 0.4534
# Epoch : 62, val_Loss: 2.202262807115216, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 1.1221, Train_Accuracy: 0.4359
# Epoch : 63, val_Loss: 2.1541537703754745, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.1397, Train_Accuracy: 0.4254
# Epoch : 64, val_Loss: 2.5232739671368467, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 1.1675, Train_Accuracy: 0.4242
# Epoch : 65, val_Loss: 2.3371639073452104, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.1036, Train_Accuracy: 0.4242
# Epoch : 66, val_Loss: 2.4460093418014384, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 1.1456, Train_Accuracy: 0.4452
# Epoch : 67, val_Loss: 2.2658243981477257, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.1115, Train_Accuracy: 0.4196
# Epoch : 68, val_Loss: 2.4763398928062936, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.1315, Train_Accuracy: 0.4009
# Epoch : 69, val_Loss: 2.5714209369409864, val_Accuracy : 0.411214953271028
#
# Train Finished - Train_Loss: 1.1048, Train_Accuracy: 0.4510
# Epoch : 70, val_Loss: 2.622034162004417, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.1069, Train_Accuracy: 0.4103
# Epoch : 71, val_Loss: 2.658461454872773, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 1.1217, Train_Accuracy: 0.4056
# Epoch : 72, val_Loss: 2.7188931046245255, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 1.1222, Train_Accuracy: 0.4545
# Epoch : 73, val_Loss: 2.5234624916147963, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.1313, Train_Accuracy: 0.4079
# Epoch : 74, val_Loss: 2.2603668141587874, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.0799, Train_Accuracy: 0.4557
# Epoch : 75, val_Loss: 2.857827658965209, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 1.1001, Train_Accuracy: 0.4126
# Epoch : 76, val_Loss: 2.7092838465610396, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 1.1008, Train_Accuracy: 0.4476
# Epoch : 77, val_Loss: 2.770827997510678, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.1042, Train_Accuracy: 0.4114
# Epoch : 78, val_Loss: 2.6451669496910593, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 1.1148, Train_Accuracy: 0.4114
# Epoch : 79, val_Loss: 2.5925262665080133, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.0898, Train_Accuracy: 0.4674
# Epoch : 80, val_Loss: 2.4385917699225597, val_Accuracy : 0.24299065420560748
#
# Train Finished - Train_Loss: 1.1057, Train_Accuracy: 0.4615
# Epoch : 81, val_Loss: 2.8687965892185674, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 1.0900, Train_Accuracy: 0.4464
# Epoch : 82, val_Loss: 2.943278588981272, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 1.0746, Train_Accuracy: 0.4441
# Epoch : 83, val_Loss: 2.649215733893564, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.1121, Train_Accuracy: 0.4476
# Epoch : 84, val_Loss: 2.825309682115216, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.0833, Train_Accuracy: 0.4709
# Epoch : 85, val_Loss: 2.866894695246331, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.0760, Train_Accuracy: 0.4452
# Epoch : 86, val_Loss: 2.973241574296327, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.0733, Train_Accuracy: 0.4499
# Epoch : 87, val_Loss: 2.4861091185953015, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 1.0462, Train_Accuracy: 0.4825
# Epoch : 88, val_Loss: 2.928112850010952, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 1.0836, Train_Accuracy: 0.4545
# Epoch : 89, val_Loss: 2.783524112166645, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 1.0725, Train_Accuracy: 0.4172
# Epoch : 90, val_Loss: 3.126246799932462, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 1.0514, Train_Accuracy: 0.4604
# Epoch : 91, val_Loss: 2.9842619138343314, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.0621, Train_Accuracy: 0.4744
# Epoch : 92, val_Loss: 2.6041113238468347, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 1.0830, Train_Accuracy: 0.4697
# Epoch : 93, val_Loss: 2.582333930184908, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.0843, Train_Accuracy: 0.4312
# Epoch : 94, val_Loss: 2.398648770056038, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 1.0519, Train_Accuracy: 0.4231
# Epoch : 95, val_Loss: 2.9765406457063195, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 1.0297, Train_Accuracy: 0.4336
# Epoch : 96, val_Loss: 3.3163791193026246, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.0398, Train_Accuracy: 0.4580
# Epoch : 97, val_Loss: 2.485110487893363, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 1.0708, Train_Accuracy: 0.4429
# Epoch : 98, val_Loss: 2.619988878196645, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 1.0435, Train_Accuracy: 0.4254
# Epoch : 99, val_Loss: 2.960083899096908, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 1.0416, Train_Accuracy: 0.4382
# Epoch : 100, val_Loss: 2.672593161324474, val_Accuracy : 0.3177570093457944

# %%
# 학습 실행2
for epoch in range(100):
    train(model, train_loader, optimizer)
    val_loss, val_accuracy, val_predict_history, val_label_history = evaluate(model, test_loader)
    print(f"Epoch : {epoch + 1}, val_Loss: {val_loss}, val_Accuracy : {val_accuracy}", '\n')
# Out:
# Train Finished - Train_Loss: 1.0326, Train_Accuracy: 0.4732
# Epoch : 1, val_Loss: 2.70676785763179, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 1.0590, Train_Accuracy: 0.4814
# Epoch : 2, val_Loss: 3.0651151710581557, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.0387, Train_Accuracy: 0.4580
# Epoch : 3, val_Loss: 2.530284988545926, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.0202, Train_Accuracy: 0.4697
# Epoch : 4, val_Loss: 2.96349256283769, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 1.0414, Train_Accuracy: 0.4639
# Epoch : 5, val_Loss: 3.2696960306613243, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.0339, Train_Accuracy: 0.4674
# Epoch : 6, val_Loss: 3.406126325375566, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 1.0317, Train_Accuracy: 0.4207
# Epoch : 7, val_Loss: 2.9243244278096707, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 1.0286, Train_Accuracy: 0.4825
# Epoch : 8, val_Loss: 3.28738891744168, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 1.0515, Train_Accuracy: 0.4580
# Epoch : 9, val_Loss: 2.617659773782035, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 1.0505, Train_Accuracy: 0.4744
# Epoch : 10, val_Loss: 2.989310540885569, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 1.0241, Train_Accuracy: 0.4639
# Epoch : 11, val_Loss: 2.6469760074793736, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.0062, Train_Accuracy: 0.4604
# Epoch : 12, val_Loss: 3.0713716310875436, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 1.0432, Train_Accuracy: 0.4476
# Epoch : 13, val_Loss: 3.1773701605395734, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.0182, Train_Accuracy: 0.4685
# Epoch : 14, val_Loss: 3.2009761845954112, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 1.0591, Train_Accuracy: 0.4452
# Epoch : 15, val_Loss: 3.365804190947631, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 1.0338, Train_Accuracy: 0.4627
# Epoch : 16, val_Loss: 3.163812869063048, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.0376, Train_Accuracy: 0.4755
# Epoch : 17, val_Loss: 3.2917551414988866, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 1.0515, Train_Accuracy: 0.4615
# Epoch : 18, val_Loss: 3.2638710592394675, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 1.0250, Train_Accuracy: 0.4510
# Epoch : 19, val_Loss: 3.3995392344822393, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9870, Train_Accuracy: 0.4767
# Epoch : 20, val_Loss: 2.6724312684246314, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9806, Train_Accuracy: 0.4615
# Epoch : 21, val_Loss: 2.63341105095694, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 1.0040, Train_Accuracy: 0.4674
# Epoch : 22, val_Loss: 2.846785785995911, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9918, Train_Accuracy: 0.4720
# Epoch : 23, val_Loss: 3.809640652665468, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9963, Train_Accuracy: 0.4662
# Epoch : 24, val_Loss: 3.354035315112533, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 0.9983, Train_Accuracy: 0.5023
# Epoch : 25, val_Loss: 2.5519641983174832, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9858, Train_Accuracy: 0.4627
# Epoch : 26, val_Loss: 3.528671086391556, val_Accuracy : 0.2336448598130841
#
# Train Finished - Train_Loss: 0.9885, Train_Accuracy: 0.4697
# Epoch : 27, val_Loss: 3.0776180374288113, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 0.9984, Train_Accuracy: 0.4895
# Epoch : 28, val_Loss: 3.871530871524989, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9999, Train_Accuracy: 0.4732
# Epoch : 29, val_Loss: 3.311824299464716, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9814, Train_Accuracy: 0.4557
# Epoch : 30, val_Loss: 2.8676265823506863, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9811, Train_Accuracy: 0.4977
# Epoch : 31, val_Loss: 3.296048066326391, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9930, Train_Accuracy: 0.4988
# Epoch : 32, val_Loss: 3.543964279032199, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 0.9730, Train_Accuracy: 0.4814
# Epoch : 33, val_Loss: 3.4042169802656796, val_Accuracy : 0.3925233644859813
#
# Train Finished - Train_Loss: 0.9468, Train_Accuracy: 0.4860
# Epoch : 34, val_Loss: 3.3155484065831264, val_Accuracy : 0.3177570093457944
#
# Train Finished - Train_Loss: 0.9626, Train_Accuracy: 0.4965
# Epoch : 35, val_Loss: 3.4096335295204803, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 0.9733, Train_Accuracy: 0.4709
# Epoch : 36, val_Loss: 3.5118785751200168, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 1.0238, Train_Accuracy: 0.4627
# Epoch : 37, val_Loss: 3.1204849314466814, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9651, Train_Accuracy: 0.4883
# Epoch : 38, val_Loss: 3.6035335219909097, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9883, Train_Accuracy: 0.4837
# Epoch : 39, val_Loss: 3.5233988895594517, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9948, Train_Accuracy: 0.4312
# Epoch : 40, val_Loss: 3.5016542951637337, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9751, Train_Accuracy: 0.4965
# Epoch : 41, val_Loss: 3.9127351279570677, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 0.9481, Train_Accuracy: 0.4860
# Epoch : 42, val_Loss: 3.099094533474646, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9400, Train_Accuracy: 0.4872
# Epoch : 43, val_Loss: 2.8326698018011647, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 0.9508, Train_Accuracy: 0.4767
# Epoch : 44, val_Loss: 2.830861563994506, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9395, Train_Accuracy: 0.4977
# Epoch : 45, val_Loss: 3.745905546384437, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9278, Train_Accuracy: 0.5070
# Epoch : 46, val_Loss: 2.734867381158276, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 0.9606, Train_Accuracy: 0.4802
# Epoch : 47, val_Loss: 3.8051945338739412, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9613, Train_Accuracy: 0.4965
# Epoch : 48, val_Loss: 3.2843560192072503, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9282, Train_Accuracy: 0.5035
# Epoch : 49, val_Loss: 2.8617287751670197, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9591, Train_Accuracy: 0.4872
# Epoch : 50, val_Loss: 3.7678718210380766, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9356, Train_Accuracy: 0.4965
# Epoch : 51, val_Loss: 3.551011343982732, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9315, Train_Accuracy: 0.4814
# Epoch : 52, val_Loss: 3.805285480534919, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 0.9311, Train_Accuracy: 0.4988
# Epoch : 53, val_Loss: 3.5309522753563996, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9121, Train_Accuracy: 0.4674
# Epoch : 54, val_Loss: 3.838150523533331, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9593, Train_Accuracy: 0.4767
# Epoch : 55, val_Loss: 3.6229762496235214, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.9446, Train_Accuracy: 0.4406
# Epoch : 56, val_Loss: 3.0204779366466488, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9506, Train_Accuracy: 0.5093
# Epoch : 57, val_Loss: 4.06833780591733, val_Accuracy : 0.38317757009345793
#
# Train Finished - Train_Loss: 0.9143, Train_Accuracy: 0.5035
# Epoch : 58, val_Loss: 3.5299824866178993, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 0.9558, Train_Accuracy: 0.4895
# Epoch : 59, val_Loss: 3.411191031197521, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 0.9102, Train_Accuracy: 0.4930
# Epoch : 60, val_Loss: 3.9384385937842254, val_Accuracy : 0.40186915887850466
#
# Train Finished - Train_Loss: 0.9362, Train_Accuracy: 0.5035
# Epoch : 61, val_Loss: 3.695879962956794, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9216, Train_Accuracy: 0.4953
# Epoch : 62, val_Loss: 4.17377646615572, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9164, Train_Accuracy: 0.4860
# Epoch : 63, val_Loss: 3.7242914716774056, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9387, Train_Accuracy: 0.4848
# Epoch : 64, val_Loss: 3.0967792974454222, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.8990, Train_Accuracy: 0.5082
# Epoch : 65, val_Loss: 3.46143825923171, val_Accuracy : 0.2616822429906542
#
# Train Finished - Train_Loss: 0.9374, Train_Accuracy: 0.4860
# Epoch : 66, val_Loss: 3.7483045631479994, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9014, Train_Accuracy: 0.4814
# Epoch : 67, val_Loss: 3.6993100888261172, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9406, Train_Accuracy: 0.5117
# Epoch : 68, val_Loss: 3.8602204723892926, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9096, Train_Accuracy: 0.4767
# Epoch : 69, val_Loss: 4.155267162857768, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.9230, Train_Accuracy: 0.4848
# Epoch : 70, val_Loss: 4.003570627943378, val_Accuracy : 0.308411214953271
#
# Train Finished - Train_Loss: 0.9175, Train_Accuracy: 0.4814
# Epoch : 71, val_Loss: 2.963844192362277, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.8997, Train_Accuracy: 0.5221
# Epoch : 72, val_Loss: 3.598211841048481, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9342, Train_Accuracy: 0.5186
# Epoch : 73, val_Loss: 4.054230413704275, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9688, Train_Accuracy: 0.4779
# Epoch : 74, val_Loss: 3.9740344965569325, val_Accuracy : 0.27102803738317754
#
# Train Finished - Train_Loss: 0.9219, Train_Accuracy: 0.4674
# Epoch : 75, val_Loss: 3.9579520537474444, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 0.8978, Train_Accuracy: 0.5303
# Epoch : 76, val_Loss: 4.064200641952943, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 0.9272, Train_Accuracy: 0.4895
# Epoch : 77, val_Loss: 4.133431586149697, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.8783, Train_Accuracy: 0.4988
# Epoch : 78, val_Loss: 3.914017472311715, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 0.8754, Train_Accuracy: 0.5140
# Epoch : 79, val_Loss: 4.061040824818834, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.8984, Train_Accuracy: 0.5070
# Epoch : 80, val_Loss: 4.3548415353365035, val_Accuracy : 0.3364485981308411
#
# Train Finished - Train_Loss: 0.9029, Train_Accuracy: 0.4860
# Epoch : 81, val_Loss: 3.9857731043735396, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.8876, Train_Accuracy: 0.5152
# Epoch : 82, val_Loss: 4.070534608074438, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.8869, Train_Accuracy: 0.5163
# Epoch : 83, val_Loss: 4.330023614045616, val_Accuracy : 0.4205607476635514
#
# Train Finished - Train_Loss: 0.8945, Train_Accuracy: 0.4744
# Epoch : 84, val_Loss: 3.9687966676515956, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 0.9086, Train_Accuracy: 0.4988
# Epoch : 85, val_Loss: 4.023827472579813, val_Accuracy : 0.2523364485981308
#
# Train Finished - Train_Loss: 0.8676, Train_Accuracy: 0.4988
# Epoch : 86, val_Loss: 3.5915017529068707, val_Accuracy : 0.37383177570093457
#
# Train Finished - Train_Loss: 0.8969, Train_Accuracy: 0.5047
# Epoch : 87, val_Loss: 3.3284163786986163, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.8967, Train_Accuracy: 0.5198
# Epoch : 88, val_Loss: 4.112856998621861, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9047, Train_Accuracy: 0.5012
# Epoch : 89, val_Loss: 2.9783069574944325, val_Accuracy : 0.3644859813084112
#
# Train Finished - Train_Loss: 0.9173, Train_Accuracy: 0.4988
# Epoch : 90, val_Loss: 4.483478439188449, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.8959, Train_Accuracy: 0.5221
# Epoch : 91, val_Loss: 3.5452956440292787, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9096, Train_Accuracy: 0.5047
# Epoch : 92, val_Loss: 3.845523620320258, val_Accuracy : 0.32710280373831774
#
# Train Finished - Train_Loss: 0.9109, Train_Accuracy: 0.5140
# Epoch : 93, val_Loss: 4.339059740583473, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.9036, Train_Accuracy: 0.5105
# Epoch : 94, val_Loss: 3.2862143115462543, val_Accuracy : 0.2897196261682243
#
# Train Finished - Train_Loss: 0.8537, Train_Accuracy: 0.5245
# Epoch : 95, val_Loss: 3.169619872191242, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.8740, Train_Accuracy: 0.5058
# Epoch : 96, val_Loss: 3.0081731849741713, val_Accuracy : 0.34579439252336447
#
# Train Finished - Train_Loss: 0.8845, Train_Accuracy: 0.5105
# Epoch : 97, val_Loss: 4.38801867048317, val_Accuracy : 0.2803738317757009
#
# Train Finished - Train_Loss: 0.8810, Train_Accuracy: 0.5082
# Epoch : 98, val_Loss: 4.123124915862752, val_Accuracy : 0.35514018691588783
#
# Train Finished - Train_Loss: 0.8973, Train_Accuracy: 0.4988
# Epoch : 99, val_Loss: 4.245394376950843, val_Accuracy : 0.29906542056074764
#
# Train Finished - Train_Loss: 0.8731, Train_Accuracy: 0.4779
# Epoch : 100, val_Loss: 3.2785639183543553, val_Accuracy : 0.34579439252336447
